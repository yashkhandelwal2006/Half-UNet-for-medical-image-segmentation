# %% [markdown]
# Library Imports and Initializations

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
from sklearn import preprocessing
import pandas as pd
from sklearn.model_selection import train_test_split
import cv2
from keras.layers import *
from keras import backend as K
import os
import random
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
DRIVE_PATH = '/content/gdrive'
FOLDER_PATH = '/content/gdrive/MyDrive/CS 577/Processed_Dataset/'
drive.mount(DRIVE_PATH)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Data Generator Creation

# %%
# Creating custom data generator for data loading
class DataGen(keras.utils.Sequence):
    def __init__(self, ids, path, batch_size=2, image_size=256):
        self.ids = ids
        self.path = FOLDER_PATH + path
        self.batch_size = batch_size
        self.image_size = image_size
        self.on_epoch_end()
        
    def __load__(self, id_name):
        ## Path
        image_path = os.path.join(self.path, "images", "img" , id_name)
        mask_path = os.path.join(self.path, "mask", "img", id_name)
        all_masks = [mask_path]
        
        ## Reading Image
        image = cv2.imread(image_path)
        image = cv2.resize(image, (self.image_size, self.image_size))
        # image = np.expand_dims(image, axis=-1)
        
        mask = np.zeros((self.image_size, self.image_size, 1))
        
        ## Reading Masks
        for name in all_masks:
            _mask_path = name
            _mask_image = cv2.imread(_mask_path, cv2.IMREAD_GRAYSCALE)
            _mask_image = cv2.resize(_mask_image, (self.image_size, self.image_size)) #128x128
            _mask_image = np.expand_dims(_mask_image, axis=-1)
            mask = np.maximum(mask, _mask_image)
            
        ## Normalizing 
        image = image/255.0
        mask = mask/255.0
        
        return image, mask
    
    def __getitem__(self, index):
        if(index+1)*self.batch_size > len(self.ids):
            self.batch_size = len(self.ids) - index*self.batch_size
        
        files_batch = self.ids[index*self.batch_size : (index+1)*self.batch_size]
        
        image = []
        mask  = []
        
        for id_name in files_batch:
            _img, _mask = self.__load__(id_name)
            image.append(_img)
            mask.append(_mask)
            
        image = np.array(image)
        mask  = np.array(mask)
        
        return image, mask
    
    def on_epoch_end(self):
        pass
    
    def __len__(self):
        return int(np.ceil(len(self.ids)/float(self.batch_size)))


def check_images():
    image_size = 256
    train_path = FOLDER_PATH + "training/images/img"
    test_path = FOLDER_PATH + "testing/images/img"
    validation_path = FOLDER_PATH + "validation/images/img"
    epochs = 10
    batch_size = 2

      ## Training Ids

    train_ids = os.listdir(train_path)
    validation_ids = os.listdir(validation_path)
    test_ids = os.listdir(test_path)
    gen = DataGen(train_ids, "training/", batch_size=batch_size, image_size=image_size)
    x, y = gen.__getitem__(0)
    print(x.shape, y.shape)
    r = random.randint(0, len(x)-1)

    fig = plt.figure()
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(np.reshape(x[0], (image_size, image_size, 3)), cmap="gray")
    ax = fig.add_subplot(1, 2, 2)
    ax.imshow(np.reshape(y[0], (image_size, image_size)), cmap="gray")
    plt.show()

    fig = plt.figure()
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(np.reshape(x[1], (image_size, image_size, 3)), cmap="gray")
    ax = fig.add_subplot(1, 2, 2)
    ax.imshow(np.reshape(y[1], (image_size, image_size)), cmap="gray")
    plt.show()
print(os.listdir(FOLDER_PATH))
check_images()
# Out:
# ['Trained_Models', 'training', 'testing', 'validation']
# (2, 256, 256, 3) (2, 256, 256, 1)

# %%
def train_data_aug(batch_size = 2):
    seed = 1
    image_datagen = ImageDataGenerator(rotation_range=0.2, rescale=1./255, width_shift_range=0.05, 
                    height_shift_range=0.05, shear_range=0.05, zoom_range=0.05,
                    horizontal_flip=True, fill_mode='nearest') 
    mask_datagen = ImageDataGenerator(rotation_range=0.2, rescale=1./255, width_shift_range=0.05,
                    height_shift_range=0.05, shear_range=0.05, zoom_range=0.05,
                    horizontal_flip=True, fill_mode='nearest')  
    dir = FOLDER_PATH + 'training/'
    image_generator = image_datagen.flow_from_directory(dir + 'images', class_mode=None, seed=seed, 
                    color_mode="grayscale", target_size=(256,256), batch_size=batch_size)
    mask_generator = mask_datagen.flow_from_directory(dir + 'mask', class_mode=None, seed=seed, 
                    color_mode="grayscale", target_size=(256,256), batch_size=batch_size)
    train_generator = zip(image_generator, mask_generator) 
    return train_generator

def test_data_aug():
    seed = 1
    image_datagen = ImageDataGenerator(rescale=1./255)
    mask_datagen = ImageDataGenerator(rescale=1./255)  
    dir = FOLDER_PATH + 'testing/'
    image_generator = image_datagen.flow_from_directory(dir + 'images', shuffle=False, class_mode=None, 
                    seed=seed, color_mode="grayscale", target_size=(256,256), batch_size=1)
    mask_generator = mask_datagen.flow_from_directory(dir + 'mask', shuffle=False, class_mode=None, 
                    seed=seed, color_mode="grayscale", target_size=(256,256), batch_size=1)
    test_generator = zip(image_generator, mask_generator) 
    return test_generator

# %%
def check_data_generator_images(c = 0):
    f, axarr = plt.subplots(1,2, figsize=(15, 15))
    for i in train_data_aug():
        if c >= 20:
            break
    im = i[0][0][:,:,0]
    ms = i[1][0][:,:,0]
    axarr[0].imshow(im)
    axarr[1].imshow(ms)
    c += 1
plt.show()

# %% [markdown]
# Half-Unet architecture With Batch Normalization (best variant of Half-Unet)

# %%
# code for Half-UNet architecture based on the research paper
def ghost_module(inputs):
    conv1 = Conv2D(32, 3, padding = 'same', kernel_initializer = 'he_normal')(inputs)
    batch1 = BatchNormalization()(conv1)
    act1 = Activation('relu')(batch1)
    conv2 = SeparableConv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(act1)
    return concatenate([act1, conv2], axis = 3)

def model(input_shape = (256, 256, 1)):

    inputs = Input(shape=input_shape, name="image")
    x1 = ghost_module(ghost_module(inputs))
    pool1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x2 = ghost_module(ghost_module(pool1))
    pool2 = MaxPooling2D(pool_size=(2, 2))(x2)
    x3 = ghost_module(ghost_module(pool2))
    pool3 = MaxPooling2D(pool_size=(2, 2))(x3)
    x4 = ghost_module(ghost_module(pool3))
    pool4 = MaxPooling2D(pool_size=(2, 2))(x4)
    x5 = ghost_module(ghost_module(pool4))

    up5 = UpSampling2D(size = (input_shape[0] // x5.shape[1], input_shape[1] // x5.shape[2]))(x5)
    up4 = UpSampling2D(size = (input_shape[0] // x4.shape[1], input_shape[1] // x4.shape[2]))(x4)
    up3 = UpSampling2D(size = (input_shape[0] // x3.shape[1], input_shape[1] // x3.shape[2]))(x3)
    up2 = UpSampling2D(size = (input_shape[0] // x2.shape[1], input_shape[1] // x2.shape[2]))(x2)

    upScaled = Add()([x1, up2, up3, up4, up5])
    all_conv = ghost_module(ghost_module(upScaled))
    final_conv = Conv2D(1, 1, activation = 'sigmoid')(all_conv)
  
    # final_conv = Conv2D(2, (1, 1), activation = 'softmax')(all_conv)
    half_unet_model = tf.keras.Model(inputs, final_conv, name="Half-UNet")
    return half_unet_model

# %% [markdown]
# UNet Architecture

# %%
#code for base version of UNet Architecture 
from keras.models import Model

def main_conv_block(input, num):
    conv = Activation("relu")(BatchNormalization()(Conv2D(num, 3, padding="same")(input)))
    conv = Activation("relu")(BatchNormalization()(Conv2D(num, 3, padding="same")(conv)))
    return conv

def left_block(input, num):
    conv = main_conv_block(input, num)
    pool = MaxPool2D((2, 2))(conv)
    return conv, pool

def right_block(input, skip_connect, num):
    conv = main_conv_block(Concatenate()([Conv2DTranspose(num, (2, 2), strides=2, padding="same")(input), skip_connect]), num)
    return conv

def unet_model(input_shape = (256, 256, 3)):
    inputs = Input(input_shape)

    conv1, pool1 = left_block(inputs, 64)
    conv2, pool2 = left_block(pool1, 128)
    conv3, pool3 = left_block(pool2, 256)
    conv4, pool4 = left_block(pool3, 512)

    bottlneck = main_conv_block(pool4, 1024)

    out1 = right_block(bottlneck, conv4, 512)
    out2 = right_block(out1, conv3, 256)
    out3 = right_block(out2, conv2, 128)
    out4 = right_block(out3, conv1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(out4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %% [markdown]
# Nested Half-Unet Model

# %%
#code for Nested Half-UNet architecture based on U^2-Net

def half_unet_block(inputs):
    x1 = ghost_module(ghost_module(inputs))
    return x1, MaxPooling2D(pool_size=(2, 2))(x1)

def half_unet_model_modified(inp, depth = 5, input_shape = 256):
    all_skips = []
    for dp in range(depth):
        x, p = half_unet_block(inp)
        inp = p
        all_skips.append(x)
    layers_to_add = []
    for i, skip in enumerate(all_skips):
        if i == 0:
            layers_to_add.append(skip)
            continue
    up = UpSampling2D(size = (input_shape // skip.shape[1], input_shape // skip.shape[2]))(skip)
    layers_to_add.append(up)

    upScaled = Add()(layers_to_add)
    return upScaled
    # return ghost_module(ghost_module(upScaled))

def nested_half_unet(input_shape = (256, 256, 3)):
    inputs = Input(shape=input_shape, name="image")
    x1 =  half_unet_model_modified(inputs, depth = 4)
    pool1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x2 =  half_unet_model_modified(pool1, depth = 3, input_shape = 128)
    pool2 = MaxPooling2D(pool_size=(2, 2))(x2)
    x3 =  half_unet_model_modified(pool2, depth = 3, input_shape = 64)
    pool3 = MaxPooling2D(pool_size=(2, 2))(x3)
    x4 =  half_unet_model_modified(pool3, depth = 2, input_shape = 32)
    pool4 = MaxPooling2D(pool_size=(2, 2))(x4)
    x5 =  half_unet_model_modified(pool4, depth = 1, input_shape = 16)

    up5 = UpSampling2D(size = (input_shape[0] // x5.shape[1], input_shape[1] // x5.shape[2]))(x5)
    up4 = UpSampling2D(size = (input_shape[0] // x4.shape[1], input_shape[1] // x4.shape[2]))(x4)
    up3 = UpSampling2D(size = (input_shape[0] // x3.shape[1], input_shape[1] // x3.shape[2]))(x3)
    up2 = UpSampling2D(size = (input_shape[0] // x2.shape[1], input_shape[1] // x2.shape[2]))(x2)
    upScaled = Add()([x1, up2, up3, up4, up5])
    all_conv = half_unet_model_modified(upScaled)

    final_conv = Conv2D(1, 1, activation = 'sigmoid')(all_conv)
  
    # final_conv = Conv2D(2, (1, 1), activation = 'softmax')(all_conv)
    half_unet_model = tf.keras.Model(inputs, final_conv, name="Half-UNet")
    return half_unet_model

# %% [markdown]
# Half-Unet Model Summary

# %%
half_unet_model = model((256, 256, 3))
half_unet_model.summary()
# from keras.utils import plot_model
# plot_model(half_unet_model, to_file = 'arch.png', show_shapes = True, show_layer_activations = True)
# Out:
# Model: "Half-UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 32  896         ['image[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 32  128        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 256, 256, 32  1344       ['activation_18[0][0]']
#  v2D)                           )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 64  0           ['activation_18[0][0]',
#                                 )                                 'separable_conv2d[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 256, 256, 32  1344       ['activation_19[0][0]']
#  onv2D)                         )
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 64  0           ['activation_19[0][0]',
#                                 )                                 'separable_conv2d_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64  0          ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 32  18464       ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  separable_conv2d_2 (SeparableC  (None, 128, 128, 32  1344       ['activation_20[0][0]']
#  onv2D)                         )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 64  0           ['activation_20[0][0]',
#                                 )                                 'separable_conv2d_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  separable_conv2d_3 (SeparableC  (None, 128, 128, 32  1344       ['activation_21[0][0]']
#  onv2D)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 64  0           ['activation_21[0][0]',
#                                 )                                 'separable_conv2d_3[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['concatenate_7[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 32)   18464       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_22[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 64, 64, 32)  1344        ['activation_22[0][0]']
#  onv2D)
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 64)   0           ['activation_22[0][0]',
#                                                                   'separable_conv2d_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_23[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 64, 64, 32)  1344        ['activation_23[0][0]']
#  onv2D)
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 64)   0           ['activation_23[0][0]',
#                                                                   'separable_conv2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['concatenate_9[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 32)   18464       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 32)  128         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 32, 32, 32)  1344        ['activation_24[0][0]']
#  onv2D)
#
#  concatenate_10 (Concatenate)   (None, 32, 32, 64)   0           ['activation_24[0][0]',
#                                                                   'separable_conv2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_10[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_25[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 32, 32, 32)  1344        ['activation_25[0][0]']
#  onv2D)
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 64)   0           ['activation_25[0][0]',
#                                                                   'separable_conv2d_7[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)  0           ['concatenate_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 32)   18464       ['max_pooling2d_7[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_26[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 16, 16, 32)  1344        ['activation_26[0][0]']
#  onv2D)
#
#  concatenate_12 (Concatenate)   (None, 16, 16, 64)   0           ['activation_26[0][0]',
#                                                                   'separable_conv2d_8[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 32)   18464       ['concatenate_12[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 16, 16, 32)  1344        ['activation_27[0][0]']
#  onv2D)
#
#  concatenate_13 (Concatenate)   (None, 16, 16, 64)   0           ['activation_27[0][0]',
#                                                                   'separable_conv2d_9[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64  0          ['concatenate_7[0][0]']
#                                 )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 64  0          ['concatenate_9[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 256, 256, 64  0          ['concatenate_11[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 256, 256, 64  0           ['concatenate_13[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 64  0           ['concatenate_5[0][0]',
#                                 )                                 'up_sampling2d_3[0][0]',
#                                                                   'up_sampling2d_2[0][0]',
#                                                                   'up_sampling2d_1[0][0]',
#                                                                   'up_sampling2d[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 32  18464       ['add[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 256, 256, 32  128        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  separable_conv2d_10 (Separable  (None, 256, 256, 32  1344       ['activation_28[0][0]']
#  Conv2D)                        )
#
#  concatenate_14 (Concatenate)   (None, 256, 256, 64  0           ['activation_28[0][0]',
#                                 )                                 'separable_conv2d_10[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_14[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 256, 256, 32  128        ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  separable_conv2d_11 (Separable  (None, 256, 256, 32  1344       ['activation_29[0][0]']
#  Conv2D)                        )
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 64  0           ['activation_29[0][0]',
#                                 )                                 'separable_conv2d_11[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 1)  65          ['concatenate_15[0][0]']
#
# ==================================================================================================
# Total params: 221,729
# Trainable params: 220,961
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %% [markdown]
# Unet Model Summary

# %%
unet_model = unet_model((256, 256, 3))
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# Nested Half-Unet Model Summary

# %%
nested_half_unet = nested_half_unet((256, 256, 3))
nested_half_unet.summary()
# Out:
# Model: "Half-UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 32  896         ['image[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 256, 256, 32  128        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  activation_42 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 32  9248        ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 256, 256, 32  128        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 256, 256, 64  0           ['activation_42[0][0]',
#                                 )                                 'activation_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_16[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 256, 256, 32  128        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 32  9248        ['activation_44[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 256, 256, 32  128        ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  activation_45 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 256, 256, 64  0           ['activation_44[0][0]',
#                                 )                                 'activation_45[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 128, 128, 64  0          ['concatenate_17[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 128, 128, 32  18464       ['max_pooling2d_8[0][0]']
#                                 )
#
#  batch_normalization_46 (BatchN  (None, 128, 128, 32  128        ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  activation_46 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_46[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 128, 128, 32  9248        ['activation_46[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 128, 128, 32  128        ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  activation_47 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_47[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 128, 128, 64  0           ['activation_46[0][0]',
#                                 )                                 'activation_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_18[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 32  128        ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 32  9248        ['activation_48[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 32  128        ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  concatenate_19 (Concatenate)   (None, 128, 128, 64  0           ['activation_48[0][0]',
#                                 )                                 'activation_49[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 64)  0           ['concatenate_19[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 32)   18464       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_51[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 64, 64, 64)   0           ['activation_50[0][0]',
#                                                                   'activation_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_20[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 32)  128         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 32)  128         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_53[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 64, 64, 64)   0           ['activation_52[0][0]',
#                                                                   'activation_53[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 64)  0           ['concatenate_21[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 32)   18464       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 32)  128         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 32)  128         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_55[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 32, 32, 64)   0           ['activation_54[0][0]',
#                                                                   'activation_55[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_22[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 32)  128         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 32, 32, 32)  128         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_57[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 32, 32, 64)   0           ['activation_56[0][0]',
#                                                                   'activation_57[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 64  0          ['concatenate_23[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 256, 256, 64  0           ['concatenate_17[0][0]',
#                                 )                                 'up_sampling2d_4[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 128, 128, 64  0          ['add_1[0][0]']
#  )                              )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 32  18464       ['max_pooling2d_12[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 128, 128, 32  128        ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  activation_58 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_58[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 32  9248        ['activation_58[0][0]']
#                                 )
#
#  batch_normalization_59 (BatchN  (None, 128, 128, 32  128        ['conv2d_61[0][0]']
#  ormalization)                  )
#
#  activation_59 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_59[0][0]']
#                                 )
#
#  concatenate_24 (Concatenate)   (None, 128, 128, 64  0           ['activation_58[0][0]',
#                                 )                                 'activation_59[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_24[0][0]']
#                                 )
#
#  batch_normalization_60 (BatchN  (None, 128, 128, 32  128        ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  activation_60 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_60[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 32  9248        ['activation_60[0][0]']
#                                 )
#
#  batch_normalization_61 (BatchN  (None, 128, 128, 32  128        ['conv2d_63[0][0]']
#  ormalization)                  )
#
#  activation_61 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_61[0][0]']
#                                 )
#
#  concatenate_25 (Concatenate)   (None, 128, 128, 64  0           ['activation_60[0][0]',
#                                 )                                 'activation_61[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 64, 64, 64)  0           ['concatenate_25[0][0]']
#  )
#
#  conv2d_64 (Conv2D)             (None, 64, 64, 32)   18464       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 64, 64, 32)  128         ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_62[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 64, 64, 32)  128         ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_63[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 64, 64, 64)   0           ['activation_62[0][0]',
#                                                                   'activation_63[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_26[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 64, 64, 32)  128         ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_64[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 64, 64, 32)  128         ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_65[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 64, 64, 64)   0           ['activation_64[0][0]',
#                                                                   'activation_65[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 32, 64)  0           ['concatenate_27[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 32)   18464       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 32, 32, 32)  128         ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_66[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 32, 32, 32)  128         ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_67[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 32, 32, 64)   0           ['activation_66[0][0]',
#                                                                   'activation_67[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_28[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 32, 32, 32)  128         ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_68[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_68[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 32, 32, 32)  128         ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_69[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 32, 32, 64)   0           ['activation_68[0][0]',
#                                                                   'activation_69[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 64  0          ['concatenate_29[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 64  0           ['concatenate_25[0][0]',
#                                 )                                 'up_sampling2d_5[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 64, 64, 64)  0           ['add_2[0][0]']
#  )
#
#  conv2d_72 (Conv2D)             (None, 64, 64, 32)   18464       ['max_pooling2d_16[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 64, 64, 32)  128         ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_70[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_70[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 64, 64, 32)  128         ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_71[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 64, 64, 64)   0           ['activation_70[0][0]',
#                                                                   'activation_71[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_30[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 64, 64, 32)  128         ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_72[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_72[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 64, 64, 32)  128         ['conv2d_75[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_73[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 64, 64, 64)   0           ['activation_72[0][0]',
#                                                                   'activation_73[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 32, 32, 64)  0           ['concatenate_31[0][0]']
#  )
#
#  conv2d_76 (Conv2D)             (None, 32, 32, 32)   18464       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 32, 32, 32)  128         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_74[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_74[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 32, 32, 32)  128         ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_75[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 32, 32, 64)   0           ['activation_74[0][0]',
#                                                                   'activation_75[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_32[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 32, 32, 32)  128         ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_76[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_76[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 32, 32, 32)  128         ['conv2d_79[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_77[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 32, 32, 64)   0           ['activation_76[0][0]',
#                                                                   'activation_77[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 16, 16, 64)  0           ['concatenate_33[0][0]']
#  )
#
#  conv2d_80 (Conv2D)             (None, 16, 16, 32)   18464       ['max_pooling2d_18[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 16, 16, 32)  128         ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_78[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_78[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 16, 16, 32)  128         ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_79[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 16, 16, 64)   0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 16, 16, 32)   18464       ['concatenate_34[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 16, 16, 32)  128         ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_80[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_80[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 16, 16, 32)  128         ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_81[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 16, 16, 64)   0           ['activation_80[0][0]',
#                                                                   'activation_81[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 64)  0           ['concatenate_35[0][0]']
#
#  add_3 (Add)                    (None, 64, 64, 64)   0           ['concatenate_31[0][0]',
#                                                                   'up_sampling2d_6[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 32, 32, 64)  0           ['add_3[0][0]']
#  )
#
#  conv2d_84 (Conv2D)             (None, 32, 32, 32)   18464       ['max_pooling2d_20[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 32, 32, 32)  128         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_82[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 32, 32, 32)  128         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_83[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 32, 32, 64)   0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 32, 32, 32)   18464       ['concatenate_36[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 32, 32, 32)  128         ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_84 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_84[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_84[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 32, 32, 32)  128         ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_85[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 32, 32, 64)   0           ['activation_84[0][0]',
#                                                                   'activation_85[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 16, 16, 64)  0           ['concatenate_37[0][0]']
#  )
#
#  conv2d_88 (Conv2D)             (None, 16, 16, 32)   18464       ['max_pooling2d_21[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 16, 16, 32)  128         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_86[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_86[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 16, 16, 32)  128         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_87[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 16, 16, 64)   0           ['activation_86[0][0]',
#                                                                   'activation_87[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 16, 16, 32)   18464       ['concatenate_38[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 16, 16, 32)  128         ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_88 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_88[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_88[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 16, 16, 32)  128         ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_89[0][0]']
#
# ...
#  batch_normalization_98 (BatchN  (None, 128, 128, 32  128        ['conv2d_100[0][0]']
#  ormalization)                  )
#
#  activation_98 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_98[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 128, 128, 32  9248        ['activation_98[0][0]']
#                                 )
#
#  batch_normalization_99 (BatchN  (None, 128, 128, 32  128        ['conv2d_101[0][0]']
#  ormalization)                  )
#
#  activation_99 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_99[0][0]']
#                                 )
#
#  concatenate_44 (Concatenate)   (None, 128, 128, 64  0           ['activation_98[0][0]',
#                                 )                                 'activation_99[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 128, 128, 32  18464       ['concatenate_44[0][0]']
#                                 )
#
#  batch_normalization_100 (Batch  (None, 128, 128, 32  128        ['conv2d_102[0][0]']
#  Normalization)                 )
#
#  activation_100 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_100[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 128, 128, 32  9248        ['activation_100[0][0]']
#                                 )
#
#  batch_normalization_101 (Batch  (None, 128, 128, 32  128        ['conv2d_103[0][0]']
#  Normalization)                 )
#
#  activation_101 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_101[0][0]']
#                                 )
#
#  concatenate_45 (Concatenate)   (None, 128, 128, 64  0           ['activation_100[0][0]',
#                                 )                                 'activation_101[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 64, 64, 64)  0           ['concatenate_45[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 64, 64, 32)   18464       ['max_pooling2d_26[0][0]']
#
#  batch_normalization_102 (Batch  (None, 64, 64, 32)  128         ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 64, 64, 32)   9248        ['activation_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 64, 64, 32)  128         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_103[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 64, 64, 64)   0           ['activation_102[0][0]',
#                                                                   'activation_103[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 64, 64, 32)   18464       ['concatenate_46[0][0]']
#
#  batch_normalization_104 (Batch  (None, 64, 64, 32)  128         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_104[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 64, 64, 32)   9248        ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 64, 64, 32)  128         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_105[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 64, 64, 64)   0           ['activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 32, 32, 64)  0           ['concatenate_47[0][0]']
#  )
#
#  conv2d_108 (Conv2D)            (None, 32, 32, 32)   18464       ['max_pooling2d_27[0][0]']
#
#  batch_normalization_106 (Batch  (None, 32, 32, 32)  128         ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 32, 32, 32)  128         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_107[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 32, 32, 64)   0           ['activation_106[0][0]',
#                                                                   'activation_107[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 32, 32, 32)   18464       ['concatenate_48[0][0]']
#
#  batch_normalization_108 (Batch  (None, 32, 32, 32)  128         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_108[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_108[0][0]']
#
#  batch_normalization_109 (Batch  (None, 32, 32, 32)  128         ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_109[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 32, 32, 64)   0           ['activation_108[0][0]',
#                                                                   'activation_109[0][0]']
#
#  max_pooling2d_28 (MaxPooling2D  (None, 16, 16, 64)  0           ['concatenate_49[0][0]']
#  )
#
#  conv2d_112 (Conv2D)            (None, 16, 16, 32)   18464       ['max_pooling2d_28[0][0]']
#
#  batch_normalization_110 (Batch  (None, 16, 16, 32)  128         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_110[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_110[0][0]']
#
#  batch_normalization_111 (Batch  (None, 16, 16, 32)  128         ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_111[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 16, 16, 64)   0           ['activation_110[0][0]',
#                                                                   'activation_111[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 16, 16, 32)   18464       ['concatenate_50[0][0]']
#
#  batch_normalization_112 (Batch  (None, 16, 16, 32)  128         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_112[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 16, 16, 32)  128         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_113[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 16, 16, 64)   0           ['activation_112[0][0]',
#                                                                   'activation_113[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 256, 256, 64  0          ['concatenate_51[0][0]']
#  )                              )
#
#  add_7 (Add)                    (None, 256, 256, 64  0           ['concatenate_43[0][0]',
#                                 )                                 'up_sampling2d_13[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 256, 256, 1)  65          ['add_7[0][0]']
#
# ==================================================================================================
# Total params: 989,345
# Trainable params: 984,737
# Non-trainable params: 4,608
# __________________________________________________________________________________________________

# %% [markdown]
# Visualization Plots

# %%
#code for visualizing all the metrics and the loss during training
import matplotlib.pyplot as plt, random, numpy as np, cv2
from PIL import Image
from keras import backend as K

def training_history_plot(results):
	"""Plots "training curve" for the network/model for metrics listed below:
    		1. Dice loss
    		2. Pixel-wise accuracy 
    		3. Intersection Over Union(IOU)
    		4. F1 score
    		5. Recall
    		6. Precision
    Args:
        results (History): Output of 'model.fit_generator()', 'History.history' attribute is a record of metrics
        					values as described above(from 1-6)
    Returns:
        None
	"""
	titles = ["dice_loss",'accuracy', "iou", "F1", "recall", "precision", "dice_coef"] 
	metric = ['loss', 'accuracy', 'iou','F1','recall','precision','dice_coef'] # Metrics we're keeping track off
	val_metric = ['val_loss', 'val_accuracy', 'val_iou','val_F1','val_recall','val_precision','val_dice_coef']
	# Define specification of our plot
	fig, axs = plt.subplots(4,2, figsize=(15, 15), facecolor='w', edgecolor='k')
	fig.subplots_adjust(hspace = 0.5, wspace=0.2)
	axs = axs.ravel()

	for i in range(7):
		axs[i].plot(results.history[metric[i]]) # Calls from 'History.history'- 'metric[i]', note 'results' is 
		axs[i].plot(results.history[val_metric[i]])
		axs[i].set_title(titles[i])				# a 'History' object
		axs[i].set_xlabel('epoch')  
		axs[i].set_ylabel(metric[i])
		axs[i].legend(['train'], loc='upper left')

# %% [markdown]
# Evaluation Metrics Definitions

# %%
#custom loss and metrics functions
def iou(y_true, y_pred, smooth=1):
	intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
	union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
	iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
	return iou

def F1(y_true, y_pred, smooth=1):
	intersection = K.sum(y_true * y_pred, axis=[1,2,3])
	union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
	dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
	return dice

def recall(y_true, y_pred):
	true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
	possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
	recall = true_positives / (possible_positives + K.epsilon())
	return recall

def precision(y_true, y_pred):
	true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
	predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
	precision = true_positives / (predicted_positives + K.epsilon())
	return precision

def dice_coef(y_true, y_pred, smooth = 0.00001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def scheduler(epoch, lr):
      if epoch < 30:
        lr = 0.001
        return lr
      if epoch < 50:
        return 0.0005
      return 0.0001

# %% [markdown]
# Data Generators and Model Config Initializations

# %%
#initializing data generators
btch_size = 2
image_size = 256

train_path = FOLDER_PATH + "training/images/img"
test_path = FOLDER_PATH + "testing/images/img"
validation_path = FOLDER_PATH + "validation/images/img"

train_ids = os.listdir(train_path)
validation_ids = os.listdir(validation_path)
test_ids = os.listdir(test_path)

# %% [markdown]
# Basic Half-Unet Model Training

# %%
#training code for half-UNet (The output is for the base half-UNet model)
train_gen = DataGen(train_ids, 'training/', image_size=image_size, batch_size=btch_size)
valid_gen = DataGen(validation_ids, 'validation/', image_size=image_size, batch_size=btch_size)
train_steps = len(train_ids)//btch_size
valid_steps = len(validation_ids)//btch_size
half_unet_model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'binary_crossentropy', metrics = ['accuracy', iou, F1, recall, precision, dice_coef])
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = half_unet_model.fit_generator(train_gen, validation_data=valid_gen, steps_per_epoch=train_steps, validation_steps=valid_steps, epochs=60, callbacks=[callback])
training_history_plot(history)
half_unet_model.save('half_unet')
# Out:
# Epoch 1/60
# 2445/2445 [==============================] - 262s 106ms/step - loss: 0.0169 - accuracy: 0.9923 - iou: 0.4903 - F1: 0.6367 - recall: 0.7543 - precision: 0.7946 - dice_coef: 0.6731 - val_loss: 0.0164 - val_accuracy: 0.9924 - val_iou: 0.5062 - val_F1: 0.6531 - val_recall: 0.8182 - val_precision: 0.7573 - val_dice_coef: 0.6840
# Epoch 2/60
# 2445/2445 [==============================] - 259s 106ms/step - loss: 0.0160 - accuracy: 0.9927 - iou: 0.5074 - F1: 0.6518 - recall: 0.7671 - precision: 0.8041 - dice_coef: 0.6883 - val_loss: 0.0167 - val_accuracy: 0.9924 - val_iou: 0.4646 - val_F1: 0.6132 - val_recall: 0.6951 - val_precision: 0.8379 - val_dice_coef: 0.6498
# Epoch 3/60
# 2445/2445 [==============================] - 273s 112ms/step - loss: 0.0152 - accuracy: 0.9931 - iou: 0.5220 - F1: 0.6641 - recall: 0.7795 - precision: 0.8119 - dice_coef: 0.7017 - val_loss: 0.0168 - val_accuracy: 0.9925 - val_iou: 0.5267 - val_F1: 0.6686 - val_recall: 0.7262 - val_precision: 0.8278 - val_dice_coef: 0.7009
# Epoch 4/60
# 2445/2445 [==============================] - 280s 114ms/step - loss: 0.0148 - accuracy: 0.9933 - iou: 0.5318 - F1: 0.6722 - recall: 0.7859 - precision: 0.8160 - dice_coef: 0.7103 - val_loss: 0.0153 - val_accuracy: 0.9930 - val_iou: 0.5139 - val_F1: 0.6578 - val_recall: 0.8027 - val_precision: 0.7904 - val_dice_coef: 0.6926
# Epoch 5/60
# 2445/2445 [==============================] - 279s 114ms/step - loss: 0.
60
# 2445/2445 [==============================] - 279s 114ms/step - loss: 0.0032 - accuracy: 0.9981 - iou: 0.8490 - F1: 0.9124 - recall: 0.9466 - precision: 0.9526 - dice_coef: 0.9338 - val_loss: 0.0301 - val_accuracy: 0.9939 - val_iou: 0.6638 - val_F1: 0.7714 - val_recall: 0.8181 - val_precision: 0.8258 - val_dice_coef: 0.8049
# Epoch 57/60
# 2445/2445 [==============================] - 280s 115ms/step - loss: 0.0031 - accuracy: 0.9981 - iou: 0.8519 - F1: 0.9143 - recall: 0.9477 - precision: 0.9534 - dice_coef: 0.9352 - val_loss: 0.0309 - val_accuracy: 0.9939 - val_iou: 0.6632 - val_F1: 0.7708 - val_recall: 0.8155 - val_precision: 0.8259 - val_dice_coef: 0.8042
# Epoch 58/60
# 2445/2445 [==============================] - 279s 114ms/step - loss: 0.0030 - accuracy: 0.9982 - iou: 0.8546 - F1: 0.9160 - recall: 0.9490 - precision: 0.9543 - dice_coef: 0.9366 - val_loss: 0.0309 - val_accuracy: 0.9939 - val_iou: 0.6651 - val_F1: 0.7727 - val_recall: 0.8203 - val_precision: 0.8237 - val_dice_coef: 0.8055
# Epoch 59/60
# 2445/2445 [==============================] - 280s 115ms/step - loss: 0.0030 - accuracy: 0.9982 - iou: 0.8567 - F1: 0.9172 - recall: 0.9498 - precision: 0.9554 - dice_coef: 0.9377 - val_loss: 0.0319 - val_accuracy: 0.9939 - val_iou: 0.6643 - val_F1: 0.7717 - val_recall: 0.8216 - val_precision: 0.8215 - val_dice_coef: 0.8050
# Epoch 60/60
# 2445/2445 [==============================] - 281s 115ms/step - loss: 0.0029 - accuracy: 0.9982 - iou: 0.8586 - F1: 0.9185 - recall: 0.9503 - precision: 0.9558 - dice_coef: 0.9386 - val_loss: 0.0323 - val_accuracy: 0.9938 - val_iou: 0.6639 - val_F1: 0.7714 - val_recall: 0.8175 - val_precision: 0.8242 - val_dice_coef: 0.8046
# 2022-11-14 04:01:46.875450: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# Unet Model Training

# %%
#training code for UNet
train_gen = DataGen(train_ids, 'training/', image_size=image_size, batch_size=btch_size)
valid_gen = DataGen(validation_ids, 'validation/', image_size=image_size, batch_size=btch_size)
train_steps = len(train_ids)//btch_size
valid_steps = len(validation_ids)//btch_size
unet_model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'binary_crossentropy', metrics = ['accuracy', iou, F1, recall, precision, dice_coef])
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = unet_model.fit_generator(train_gen, validation_data=valid_gen, steps_per_epoch=train_steps, validation_steps=valid_steps, epochs=60, callbacks=[callback])
training_history_plot(history)
unet_model.save('unet')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/60
# 2445/2445 [==============================] - 202s 81ms/step - loss: 0.0383 - accuracy: 0.9857 - iou: 0.2463 - F1: 0.3698 - recall: 0.4337 - precision: 0.5868 - dice_coef: 0.3950 - val_loss: 0.0288 - val_accuracy: 0.9874 - val_iou: 0.2760 - val_F1: 0.4109 - val_recall: 0.3587 - val_precision: 0.8308 - val_dice_coef: 0.4517
# Epoch 2/60
# 2445/2445 [==============================] - 199s 81ms/step - loss: 0.0239 - accuracy: 0.9892 - iou: 0.3756 - F1: 0.5231 - recall: 0.6547 - precision: 0.7320 - dice_coef: 0.5617 - val_loss: 0.0422 - val_accuracy: 0.9888 - val_iou: 0.3050 - val_F1: 0.4138 - val_recall: 0.4449 - val_precision: 0.7497 - val_dice_coef: 0.4922
# Epoch 3/60
# 2445/2445 [==============================] - 201s 82ms/step - loss: 0.0010 - accuracy: 0.9990 - iou: 0.9504 - F1: 0.9738 - recall: 0.9842 - precision: 0.9846 - dice_coef: 0.9796 - val_loss: 0.0492 - val_accuracy: 0.9944 - val_iou: 0.6851 - val_F1: 0.7837 - val_recall: 0.8029 - val_precision: 0.8580 - val_dice_coef: 0.8150
# Epoch 59/60
# 2445/2445 [==============================] - 199s 81ms/step - loss: 0.0010 - accuracy: 0.9990 - iou: 0.9508 - F1: 0.9740 - recall: 0.9844 - precision: 0.9848 - dice_coef: 0.9798 - val_loss: 0.0544 - val_accuracy: 0.9942 - val_iou: 0.6671 - val_F1: 0.7641 - val_recall: 0.7742 - val_precision: 0.8680 - val_dice_coef: 0.8008
# Epoch 60/60
# 2445/2445 [==============================] - 211s 86ms/step - loss: 0.0010 - accuracy: 0.9990 - iou: 0.9510 - F1: 0.9741 - recall: 0.9845 - precision: 0.9849 - dice_coef: 0.9799 - val_loss: 0.0504 - val_accuracy: 0.9944 - val_iou: 0.6806 - val_F1: 0.7792 - val_recall: 0.7901 - val_precision: 0.8656 - val_dice_coef: 0.8110

# %% [markdown]
# Nested Half-Unet Model Training

# %%
#training code for Nested half-UNet
train_gen = DataGen(train_ids, 'training/', image_size=image_size, batch_size=btch_size)
valid_gen = DataGen(validation_ids, 'validation/', image_size=image_size, batch_size=btch_size)
train_steps = len(train_ids)//btch_size
valid_steps = len(validation_ids)//btch_size
nested_half_unet.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'binary_crossentropy', metrics = ['accuracy', iou, F1, recall, precision, dice_coef])
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = nested_half_unet.fit_generator(train_gen, validation_data=valid_gen, steps_per_epoch=train_steps, validation_steps=valid_steps, epochs=60, callbacks=[callback])
training_history_plot(history)
nested_half_unet.save('nested_half_unet')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/60
# 2445/2445 [==============================] - 187s 73ms/step - loss: 0.0337 - accuracy: 0.9874 - iou: 0.3104 - F1: 0.4405 - recall: 0.5313 - precision: 0.6678 - dice_coef: 0.4743 - val_loss: 0.0280 - val_accuracy: 0.9877 - val_iou: 0.3058 - val_F1: 0.4511 - val_recall: 0.4461 - val_precision: 0.8054 - val_dice_coef: 0.4734
# Epoch 2/60
# 2445/2445 [==============================] - 176s 72ms/step - loss: 0.0188 - accuracy: 0.9915 - iou: 0.4580 - F1: 0.6050 - recall: 0.7292 - precision: 0.7784 - dice_coef: 0.6443 - val_loss: 0.0171 - val_accuracy: 0.9921 - val_iou: 0.5011 - val_F1: 0.6418 - val_recall: 0.7782 - val_precision: 0.7591 - val_dice_coef: 0.6813
# Epoch 3/60
# 2445/2445 [==============================] - 176s 72ms/step - loss: 0.0171 - accuracy: 0.9922 - iou: 0.4892 - F1: 0.6356 - recall: 0.7552 - precision: 0.7935 - dice_coef: 0.6737 - val_loss: 0.0173 - val_accuracy: 0.9923 - val_iou: 0.4810 - val_F1: 0.6234 - val_recall: 0.7319 - val_precision: 0.7990 - val_dice_coef: 0.6614
# Epoch 4/60
# 2445/2445 [==============================] - 175s 72ms/step - loss: 0.0167 - accuracy: 0.9924 - iou: 0.4998 - F1: 0.6448 - recall: 0.7655 - precision: 0.7978 - dice_coef: 0.6830 - val_loss: 0.0181 - val_accuracy: 0.9914 - val_iou: 0.5261 - val_F1: 0.6656 - val_recall: 0.8766 - val_precision: 0.6937 - val_dice_coef: 0.6975
# Epoch 5/60
# 2445/2445 [==============================] - 177s 72ms/step - loss: 0.
# 2445/2445 [==============================] - 174s 71ms/step - loss: 0.0015 - accuracy: 0.9988 - iou: 0.9244 - F1: 0.9590 - recall: 0.9752 - precision: 0.9764 - dice_coef: 0.9692 - val_loss: 0.0355 - val_accuracy: 0.9948 - val_iou: 0.7186 - val_F1: 0.8133 - val_recall: 0.8524 - val_precision: 0.8508 - val_dice_coef: 0.8420
# Epoch 56/60
# 2445/2445 [==============================] - 175s 72ms/step - loss: 0.0015 - accuracy: 0.9988 - iou: 0.9262 - F1: 0.9599 - recall: 0.9758 - precision: 0.9770 - dice_coef: 0.9700 - val_loss: 0.0363 - val_accuracy: 0.9948 - val_iou: 0.7191 - val_F1: 0.8136 - val_recall: 0.8540 - val_precision: 0.8494 - val_dice_coef: 0.8422
# Epoch 57/60
# 2445/2445 [==============================] - 174s 71ms/step - loss: 0.0014 - accuracy: 0.9988 - iou: 0.9276 - F1: 0.9608 - recall: 0.9763 - precision: 0.9774 - dice_coef: 0.9705 - val_loss: 0.0368 - val_accuracy: 0.9948 - val_iou: 0.7188 - val_F1: 0.8136 - val_recall: 0.8534 - val_precision: 0.8494 - val_dice_coef: 0.8420
# Epoch 58/60
# 2445/2445 [==============================] - 174s 71ms/step - loss: 0.0014 - accuracy: 0.9988 - iou: 0.9286 - F1: 0.9613 - recall: 0.9767 - precision: 0.9779 - dice_coef: 0.9710 - val_loss: 0.0379 - val_accuracy: 0.9948 - val_iou: 0.7180 - val_F1: 0.8128 - val_recall: 0.8504 - val_precision: 0.8516 - val_dice_coef: 0.8414
# Epoch 59/60
# 2445/2445 [==============================] - 175s 71ms/step - loss: 0.0014 - accuracy: 0.9988 - iou: 0.9298 - F1: 0.9620 - recall: 0.9770 - precision: 0.9781 - dice_coef: 0.9714 - val_loss: 0.0377 - val_accuracy: 0.9948 - val_iou: 0.7189 - val_F1: 0.8139 - val_recall: 0.8562 - val_precision: 0.8468 - val_dice_coef: 0.8422
# Epoch 60/60
# 2445/2445 [==============================] - 172s 70ms/step - loss: 0.0014 - accuracy: 0.9988 - iou: 0.9305 - F1: 0.9624 - recall: 0.9772 - precision: 0.9785 - dice_coef: 0.9718 - val_loss: 0.0384 - val_accuracy: 0.9948 - val_iou: 0.7186 - val_F1: 0.8134 - val_recall: 0.8513 - val_precision: 0.8508 - val_dice_coef: 0.8417
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# Half-Unet Model Training with L2 Regularization

# %%
#training code for half-UNet (The output is for the half-UNet model with L2 Regularization)
train_gen = DataGen(train_ids, 'training/', image_size=image_size, batch_size=btch_size)
valid_gen = DataGen(validation_ids, 'validation/', image_size=image_size, batch_size=btch_size)
train_steps = len(train_ids)//btch_size
valid_steps = len(validation_ids)//btch_size
half_unet_model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'binary_crossentropy', metrics = ['accuracy', iou, F1, recall, precision, dice_coef])
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = half_unet_model.fit_generator(train_gen, validation_data=valid_gen, steps_per_epoch=train_steps, validation_steps=valid_steps, epochs=60, callbacks=[callback])
training_history_plot(history)
half_unet_model.save('half_unet_reg')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-11-14 06:23:37.515671: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-11-14 06:23:41.432037: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 
# 2445/2445 [==============================] - 274s 112ms/step - loss: 0.0167 - accuracy: 0.9930 - iou: 0.5175 - F1: 0.6615 - recall: 0.7753 - precision: 0.8097 - dice_coef: 0.6987 - val_loss: 0.0184 - val_accuracy: 0.9922 - val_iou: 0.5112 - val_F1: 0.6537 - val_recall: 0.8093 - val_precision: 0.7490 - val_dice_coef: 0.6902
# Epoch 57/60
# 2445/2445 [==============================] - 281s 115ms/step - loss: 0.0167 - accuracy: 0.9930 - iou: 0.5177 - F1: 0.6616 - recall: 0.7764 - precision: 0.8099 - dice_coef: 0.6992 - val_loss: 0.0179 - val_accuracy: 0.9925 - val_iou: 0.5137 - val_F1: 0.6574 - val_recall: 0.7577 - val_precision: 0.7949 - val_dice_coef: 0.6923
# Epoch 58/60
# 2445/2445 [==============================] - 277s 113ms/step - loss: 0.0167 - accuracy: 0.9930 - iou: 0.5187 - F1: 0.6624 - recall: 0.7763 - precision: 0.8102 - dice_coef: 0.7002 - val_loss: 0.0178 - val_accuracy: 0.9925 - val_iou: 0.5003 - val_F1: 0.6452 - val_recall: 0.7583 - val_precision: 0.7939 - val_dice_coef: 0.6814
# Epoch 59/60
# 2445/2445 [==============================] - 269s 110ms/step - loss: 0.0166 - accuracy: 0.9931 - iou: 0.5203 - F1: 0.6638 - recall: 0.7776 - precision: 0.8122 - dice_coef: 0.7015 - val_loss: 0.0181 - val_accuracy: 0.9924 - val_iou: 0.5116 - val_F1: 0.6542 - val_recall: 0.7764 - val_precision: 0.7760 - val_dice_coef: 0.6907
# Epoch 60/60
# 2445/2445 [==============================] - 278s 114ms/step - loss: 0.0165 - accuracy: 0.9931 - iou: 0.5212 - F1: 0.6646 - recall: 0.7782 - precision: 0.8124 - dice_coef: 0.7025 - val_loss: 0.0178 - val_accuracy: 0.9925 - val_iou: 0.5204 - val_F1: 0.6625 - val_recall: 0.7688 - val_precision: 0.7902 - val_dice_coef: 0.6984
# 2022-11-14 10:59:08.629348: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# Half-Unet Model Training with Batch Normalization

# %%
#training code for half-UNet (The output is for the half-UNet model with Batch Normalization)
train_gen = DataGen(train_ids, 'training/', image_size=image_size, batch_size=btch_size)
valid_gen = DataGen(validation_ids, 'validation/', image_size=image_size, batch_size=btch_size)
train_steps = len(train_ids)//btch_size
valid_steps = len(validation_ids)//btch_size
half_unet_model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'binary_crossentropy', metrics = ['accuracy', iou, F1, recall, precision, dice_coef])
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = half_unet_model.fit_generator(train_gen, validation_data=valid_gen, steps_per_epoch=train_steps, validation_steps=valid_steps, epochs=60, callbacks=[callback])
training_history_plot(history)
half_unet_model.save('half_unet_norm')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-11-14 14:31:30.176935: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-11-14 14:31:34.279999: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2445/2445 [==============================] - 126s 47ms/step - loss: 0.0368 - accuracy: 0.9869 - iou: 0.3185 - F1: 0.4499 - recall: 0.5596 - precision: 0.6634 - dice_coef: 0.4825 - val_loss: 0.0305 - val_accuracy: 0.9869 - val_iou: 0.2893 - val_F1: 0.4316 - val_recall: 0.3213 - val_precision: 0.8839 - val_dice_coef: 0.4601
# Epoch 2/60
# 2445/2445 [==============================] - 108s 44ms/step - loss: 0.
60
# 2445/2445 [==============================] - 109s 45ms/step - loss: 0.0022 - accuracy: 0.9985 - iou: 0.8888 - F1: 0.9377 - recall: 0.9631 - precision: 0.9646 - dice_coef: 0.9534 - val_loss: 0.0333 - val_accuracy: 0.9945 - val_iou: 0.6885 - val_F1: 0.7888 - val_recall: 0.8235 - val_precision: 0.8488 - val_dice_coef: 0.8218
# Epoch 56/60
# 2445/2445 [==============================] - 109s 45ms/step - loss: 0.0022 - accuracy: 0.9985 - iou: 0.8906 - F1: 0.9387 - recall: 0.9636 - precision: 0.9653 - dice_coef: 0.9542 - val_loss: 0.0337 - val_accuracy: 0.9945 - val_iou: 0.6906 - val_F1: 0.7907 - val_recall: 0.8272 - val_precision: 0.8474 - val_dice_coef: 0.8232
# Epoch 57/60
# 2445/2445 [==============================] - 109s 45ms/step - loss: 0.0021 - accuracy: 0.9985 - iou: 0.8923 - F1: 0.9397 - recall: 0.9644 - precision: 0.9658 - dice_coef: 0.9550 - val_loss: 0.0343 - val_accuracy: 0.9945 - val_iou: 0.6901 - val_F1: 0.7902 - val_recall: 0.8260 - val_precision: 0.8468 - val_dice_coef: 0.8225
# Epoch 58/60
# 2445/2445 [==============================] - 109s 45ms/step - loss: 0.0021 - accuracy: 0.9985 - iou: 0.8938 - F1: 0.9407 - recall: 0.9649 - precision: 0.9664 - dice_coef: 0.9557 - val_loss: 0.0347 - val_accuracy: 0.9944 - val_iou: 0.6909 - val_F1: 0.7908 - val_recall: 0.8285 - val_precision: 0.8445 - val_dice_coef: 0.8228
# Epoch 59/60
# 2445/2445 [==============================] - 110s 45ms/step - loss: 0.0021 - accuracy: 0.9985 - iou: 0.8951 - F1: 0.9415 - recall: 0.9654 - precision: 0.9667 - dice_coef: 0.9564 - val_loss: 0.0350 - val_accuracy: 0.9945 - val_iou: 0.6907 - val_F1: 0.7910 - val_recall: 0.8274 - val_precision: 0.8463 - val_dice_coef: 0.8231
# Epoch 60/60
# 2445/2445 [==============================] - 109s 45ms/step - loss: 0.0021 - accuracy: 0.9986 - iou: 0.8962 - F1: 0.9421 - recall: 0.9655 - precision: 0.9673 - dice_coef: 0.9568 - val_loss: 0.0363 - val_accuracy: 0.9944 - val_iou: 0.6902 - val_F1: 0.7902 - val_recall: 0.8263 - val_precision: 0.8461 - val_dice_coef: 0.8228
# 2022-11-14 16:22:32.264950: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# Model loading, evaluation and result visualization

# %%
all_mods = ['half_unet', 'half_unet_reg', 'half_unet_norm', 'unet', 'nested_half_unet']

btch_size = 2
image_size = 256

train_path = FOLDER_PATH + "training/images/img"
test_path = FOLDER_PATH + "testing/images/img"
validation_path = FOLDER_PATH + "validation/images/img"

train_ids = os.listdir(train_path)
validation_ids = os.listdir(validation_path)
test_ids = os.listdir(test_path)

def iou(y_true, y_pred, smooth=1):
	intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
	union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
	iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
	return iou

def F1(y_true, y_pred, smooth=1):
	intersection = K.sum(y_true * y_pred, axis=[1,2,3])
	union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
	dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
	return dice

def recall(y_true, y_pred):
	true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
	possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
	recall = true_positives / (possible_positives + K.epsilon())
	return recall

def precision(y_true, y_pred):
	true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
	predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
	precision = true_positives / (predicted_positives + K.epsilon())
	return precision

def dice_coef(y_true, y_pred, smooth = 0.00001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def load_model(model_name):
  #loading model
  return keras.models.load_model(FOLDER_PATH + "Trained_Models/" + model_name, custom_objects ={'iou':iou, 'F1':F1, 'recall':recall, 'precision':precision, 'dice_coef':dice_coef})

def load_models(model_name = 'all'):
  #loading all or specific model based on choice
  if model_name == 'all':
    nested_half_unet = load_model('nested_half_unet')
    half_unet_reg = load_model('half_unet_reg')
    half_unet = load_model('half_unet')
    half_unet_norm = load_model('half_unet_norm')
    unet = load_model('unet')
    print("ALL Models Loaded Successfully")
    return [half_unet, half_unet_reg, half_unet_norm, unet, nested_half_unet]
  print(model_name, "Loaded Successfully")
  return load_model(model_name)

def load_test_data(batch_size = 10):
  #loading test generator
  test_ids = os.listdir(test_path)
  gen = DataGen(test_ids, "testing/", batch_size=batch_size, image_size=image_size)
  print("Test Data Loaded")
  return gen, len(test_ids)

def visualize_output(x, y, y_pred, tot, idx, fig, title_flag = False):
  #visualizing model outputs from different models
  contours1, hierarchy = cv2.findContours(y[0].astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
  contours2, hierarchy = cv2.findContours(y_pred[0].astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
  cv2.drawContours(x[0], contours1, -1, (0, 255, 0), 3)
  cv2.drawContours(x[0], contours2, -1, (255, 0, 0), 3)
  ax = fig.add_subplot(tot, 5, idx)
  # if title_flag:
  ax.set_title(all_mods[idx - 1], fontdict={'fontsize': 20, 'fontweight': 'medium'})
  ax.imshow(np.reshape(x[0], (image_size, image_size, 3)))

def visualize_outputs_of__all_models(gen, all_models, start = 0, test_img_count = 10):
  #visualizing outputs for all the models for specific number of input images
  for i in range(start, start + test_img_count):
    x, y = gen.__getitem__(i)
    fig = plt.figure(figsize=(25,25))
    for idx, mod in enumerate(all_models):
      y_pred = mod.predict(x, verbose = 0)
      visualize_output(x.copy(), y, y_pred, test_img_count, idx+1, fig, i==start)
  plt.show()

def evaluate_all_models(gen, all_models, num_tests):
  #evaluating all models
  valid_ids = os.listdir(validation_path)
  gen = DataGen(valid_ids, "validation/", batch_size=1, image_size=image_size)
  num_tests = len(valid_ids)
  for idx, mod in enumerate(all_models):
    out = mod.evaluate_generator(gen, steps = num_tests)
    print(all_mods[idx], out[-1])

# %%
all_models = load_models() # pass any of the following as a string to load the specific model : 'half_unet', 'half_unet_reg', 'half_unet_norm', 'unet', 'nested_half_unet'
gen, num_tests = load_test_data(1) # pass any number higher than 1 which represents the batch_size for the data generator
# Out:
# ALL Models Loaded Successfully
# Test Data Loaded

# %%
#to check the output on different data run the below model with start which is the start index and test_img_count which is the total images to test on
#we have total 266 images in the testing set so the start can be anything between 0 and 265 (inclusive)
#Example : start = 3 and test_img_count = 4 means starting from image number 4 and including 4 images from there
visualize_outputs_of__all_models(gen, all_models, start = 3, test_img_count = 4)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:tensorflow:5 out of the last 20 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f401c1e17a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
evaluate_all_models(gen, all_models, num_tests)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# half_unet 0.7711232900619507
# half_unet_reg 0.6621906161308289
# half_unet_norm 0.78990638256073
# unet 0.7789193987846375
# nested_half_unet 0.8131551742553711
